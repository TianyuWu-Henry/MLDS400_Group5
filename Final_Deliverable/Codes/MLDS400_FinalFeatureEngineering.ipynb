# %% [markdown]
# # Get Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

import psycopg2
from psycopg2 import Error

# %%
try:
    connection = psycopg2.connect(user="YOUR NETID",
                                  password="YOUR PASSWORD",
                                  host="pg.analytics.northwestern.edu",
                                  port="5432",
                                  database="everything2023")

    cursor = connection.cursor()
    cursor.execute("SELECT version();")
    record = cursor.fetchone()

except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)

# %%
df = pd.read_sql("SELECT * FROM group_5.final_data;", connection);
df
# Out:
#                SKU  STORE    COST  RETAIL    SALEDATE STYPE  QUANTITY  \
# 0                3    202  123.36   440.0  2005-01-18     P         1
# 1                3    202  123.36   440.0  2005-01-29     R         1
# 2                3    303    0.00     0.0  2004-08-18     P         1
# 3                3    709    0.00     0.0  2005-08-14     P         1
# 4                3    802  123.36   440.0  2005-08-09     P         1
# ...            ...    ...     ...     ...         ...   ...       ...
# 120916891  9999997   7507   15.00    19.5  2005-04-23     P         1
# 120916892  9999997   7907   15.00    19.5  2005-05-03     P         1
# 120916893  9999997   7907   15.00    19.5  2005-05-04     R         1
# 120916894  9999997   7907   15.00    19.5  2005-05-04     P         1
# 120916895  9999997   7907   15.00    19.5  2005-07-31     P         1
#
#            ORGPRICE  SPRICE    AMT                  CITY STATE    ZIP
# 0             440.0   30.00  30.00  TAMPA                   FL  33612
# 1             440.0   30.00  30.00  TAMPA                   FL  33612
# 2               0.0   12.00  12.00  ST. ANN                 MO  63074
# 3               0.0   30.00  30.00  GLENDALE                AZ  85308
# 4             440.0   30.00  30.00  CLEARWATER              FL  33761
# ...             ...     ...    ...                   ...   ...    ...
# 120916891      39.0   39.00  39.00  HOUSTON                 TX  77056
# 120916892      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916893      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916894      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916895      39.0   26.13  26.13  FRIENDSWOOD             TX  77546
#
# [120916896 rows x 13 columns]

# %%
if (connection):
    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
# Out:
# PostgreSQL connection is closed

# %% [markdown]
# ## Impute missing values

# %%
# Replace 0s with NaN in the 'COST' column
df['COST'].replace(0, np.nan, inplace=True)

# Calculate average cost for each SKU
sku_avg_cost = df.groupby('SKU')['COST'].transform('mean')

sku_avg_cost
# Out:
# 0            123.36
# 1            123.36
# 2            123.36
# 3            123.36
# 4            123.36
#               ...
# 120916891     15.00
# 120916892     15.00
# 120916893     15.00
# 120916894     15.00
# 120916895     15.00
# Name: COST, Length: 120916896, dtype: float64

# %%
# Impute missing values in 'COST' with SKU average cost
df['COST'].fillna(sku_avg_cost, inplace=True)
df
# Out:
#                SKU  STORE    COST  RETAIL    SALEDATE STYPE  QUANTITY  \
# 0                3    202  123.36   440.0  2005-01-18     P         1
# 1                3    202  123.36   440.0  2005-01-29     R         1
# 2                3    303  123.36     0.0  2004-08-18     P         1
# 3                3    709  123.36     0.0  2005-08-14     P         1
# 4                3    802  123.36   440.0  2005-08-09     P         1
# ...            ...    ...     ...     ...         ...   ...       ...
# 120916891  9999997   7507   15.00    19.5  2005-04-23     P         1
# 120916892  9999997   7907   15.00    19.5  2005-05-03     P         1
# 120916893  9999997   7907   15.00    19.5  2005-05-04     R         1
# 120916894  9999997   7907   15.00    19.5  2005-05-04     P         1
# 120916895  9999997   7907   15.00    19.5  2005-07-31     P         1
#
#            ORGPRICE  SPRICE    AMT                  CITY STATE    ZIP
# 0             440.0   30.00  30.00  TAMPA                   FL  33612
# 1             440.0   30.00  30.00  TAMPA                   FL  33612
# 2               0.0   12.00  12.00  ST. ANN                 MO  63074
# 3               0.0   30.00  30.00  GLENDALE                AZ  85308
# 4             440.0   30.00  30.00  CLEARWATER              FL  33761
# ...             ...     ...    ...                   ...   ...    ...
# 120916891      39.0   39.00  39.00  HOUSTON                 TX  77056
# 120916892      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916893      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916894      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916895      39.0   26.13  26.13  FRIENDSWOOD             TX  77546
#
# [120916896 rows x 13 columns]

# %%
# There is no other way we can use to fix the missing value issue in COST column
df.dropna(subset=['COST'], inplace=True)
df
# Out:
#                SKU  STORE    COST  RETAIL    SALEDATE STYPE  QUANTITY  \
# 0                3    202  123.36   440.0  2005-01-18     P         1
# 1                3    202  123.36   440.0  2005-01-29     R         1
# 2                3    303  123.36     0.0  2004-08-18     P         1
# 3                3    709  123.36     0.0  2005-08-14     P         1
# 4                3    802  123.36   440.0  2005-08-09     P         1
# ...            ...    ...     ...     ...         ...   ...       ...
# 120916891  9999997   7507   15.00    19.5  2005-04-23     P         1
# 120916892  9999997   7907   15.00    19.5  2005-05-03     P         1
# 120916893  9999997   7907   15.00    19.5  2005-05-04     R         1
# 120916894  9999997   7907   15.00    19.5  2005-05-04     P         1
# 120916895  9999997   7907   15.00    19.5  2005-07-31     P         1
#
#            ORGPRICE  SPRICE    AMT                  CITY STATE    ZIP
# 0             440.0   30.00  30.00  TAMPA                   FL  33612
# 1             440.0   30.00  30.00  TAMPA                   FL  33612
# 2               0.0   12.00  12.00  ST. ANN                 MO  63074
# 3               0.0   30.00  30.00  GLENDALE                AZ  85308
# 4             440.0   30.00  30.00  CLEARWATER              FL  33761
# ...             ...     ...    ...                   ...   ...    ...
# 120916891      39.0   39.00  39.00  HOUSTON                 TX  77056
# 120916892      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916893      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916894      39.0   39.00  39.00  FRIENDSWOOD             TX  77546
# 120916895      39.0   26.13  26.13  FRIENDSWOOD             TX  77546
#
# [93387039 rows x 13 columns]

# %%
# Convert SALEDATE to datetime
df['SALEDATE'] = pd.to_datetime(df['SALEDATE'])
df['month_year'] = pd.to_datetime(df['SALEDATE'].dt.to_period('M').dt.strftime('%Y-%m'))
df.drop('SALEDATE', axis=1, inplace=True)

# %%
df
# Out:
#                SKU  STORE    COST  RETAIL STYPE  QUANTITY  ORGPRICE  SPRICE  \
# 0                3    202  123.36   440.0     P         1     440.0   30.00
# 1                3    202  123.36   440.0     R         1     440.0   30.00
# 2                3    303  123.36     0.0     P         1       0.0   12.00
# 3                3    709  123.36     0.0     P         1       0.0   30.00
# 4                3    802  123.36   440.0     P         1     440.0   30.00
# ...            ...    ...     ...     ...   ...       ...       ...     ...
# 120916891  9999997   7507   15.00    19.5     P         1      39.0   39.00
# 120916892  9999997   7907   15.00    19.5     P         1      39.0   39.00
# 120916893  9999997   7907   15.00    19.5     R         1      39.0   39.00
# 120916894  9999997   7907   15.00    19.5     P         1      39.0   39.00
# 120916895  9999997   7907   15.00    19.5     P         1      39.0   26.13
#
#              AMT                  CITY STATE    ZIP month_year
# 0          30.00  TAMPA                   FL  33612 2005-01-01
# 1          30.00  TAMPA                   FL  33612 2005-01-01
# 2          12.00  ST. ANN                 MO  63074 2004-08-01
# 3          30.00  GLENDALE                AZ  85308 2005-08-01
# 4          30.00  CLEARWATER              FL  33761 2005-08-01
# ...          ...                   ...   ...    ...        ...
# 120916891  39.00  HOUSTON                 TX  77056 2005-04-01
# 120916892  39.00  FRIENDSWOOD             TX  77546 2005-05-01
# 120916893  39.00  FRIENDSWOOD             TX  77546 2005-05-01
# 120916894  39.00  FRIENDSWOOD             TX  77546 2005-05-01
# 120916895  26.13  FRIENDSWOOD             TX  77546 2005-07-01
#
# [93387039 rows x 13 columns]

# %%
filtered_df = df[df['STYPE'] == 'P']
new_df = filtered_df.groupby(['STORE', 'month_year']).agg({
    'COST': 'sum',
    'ORGPRICE': 'mean',
    'SPRICE': 'mean',
    'AMT': 'sum',
    'QUANTITY': 'sum',
    'CITY': 'first'
}).reset_index()
new_df
# Out:
#       STORE month_year           COST   ORGPRICE     SPRICE         AMT  \
# 0       102 2004-08-01  397048.153125  41.587266  28.507850   633330.40
# 1       102 2004-09-01  449764.833499  42.377500  23.496931   596751.56
# 2       102 2004-10-01  484191.378635  40.596916  30.122991   816995.77
# 3       102 2004-11-01  465410.113387  41.804010  33.310324   843150.92
# 4       102 2004-12-01  873969.452527  41.832542  31.417166  1505699.09
# ...     ...        ...            ...        ...        ...         ...
# 4218   9909 2005-04-01  150799.454641  31.020608  23.042844   254577.34
# 4219   9909 2005-05-01  144000.158786  33.298497  24.336645   248915.20
# 4220   9909 2005-06-01  136023.043130  32.300830  23.481823   233691.10
# 4221   9909 2005-07-01  180687.260000  30.176667  18.414846   268875.17
# 4222   9909 2005-08-01  187106.888741  31.443430  18.969976   274002.34
#
#       QUANTITY                  CITY
# 0        22216  TAMPA
# 1        25397  TAMPA
# 2        27122  TAMPA
# 3        25312  TAMPA
# 4        47926  TAMPA
# ...        ...                   ...
# 4218     11048  CHEYENNE
# 4219     10228  CHEYENNE
# 4220      9952  CHEYENNE
# 4221     14601  CHEYENNE
# 4222     14444  CHEYENNE
#
# [4223 rows x 8 columns]

# %%
new_df.isnull().sum()
# Out:
# STORE         0
# month_year    0
# COST          0
# ORGPRICE      0
# SPRICE        0
# AMT           0
# QUANTITY      0
# CITY          0
# dtype: int64

# %% [markdown]
# # New feature 1: Average Cost of Goods Sold (COGS) per item sold
#
# This feature represents the average cost incurred to produce or purchase the goods that were sold within a given period. It's calculated by dividing the total Cost of Goods Sold by the number of items sold.
#
# The interpretation of this metric can provide insights into the efficiency of the business operations and profitability. Specifically, a **lower** average COGS per item sold indicates that you are generating sales while keeping the cost of producing those goods relatively low.

# %%
new_df['AvgCOGS_peritem'] = new_df['COST'] / new_df['QUANTITY']
new_df
# Out:
#       STORE month_year           COST   ORGPRICE     SPRICE         AMT  \
# 0       102 2004-08-01  397048.153125  41.587266  28.507850   633330.40
# 1       102 2004-09-01  449764.833499  42.377500  23.496931   596751.56
# 2       102 2004-10-01  484191.378635  40.596916  30.122991   816995.77
# 3       102 2004-11-01  465410.113387  41.804010  33.310324   843150.92
# 4       102 2004-12-01  873969.452527  41.832542  31.417166  1505699.09
# ...     ...        ...            ...        ...        ...         ...
# 4218   9909 2005-04-01  150799.454641  31.020608  23.042844   254577.34
# 4219   9909 2005-05-01  144000.158786  33.298497  24.336645   248915.20
# 4220   9909 2005-06-01  136023.043130  32.300830  23.481823   233691.10
# 4221   9909 2005-07-01  180687.260000  30.176667  18.414846   268875.17
# 4222   9909 2005-08-01  187106.888741  31.443430  18.969976   274002.34
#
#       QUANTITY                  CITY  AvgCOGS_peritem
# 0        22216  TAMPA                       17.872171
# 1        25397  TAMPA                       17.709369
# 2        27122  TAMPA                       17.852348
# 3        25312  TAMPA                       18.386936
# 4        47926  TAMPA                       18.235810
# ...        ...                   ...              ...
# 4218     11048  CHEYENNE                    13.649480
# 4219     10228  CHEYENNE                    14.079014
# 4220      9952  CHEYENNE                    13.667910
# 4221     14601  CHEYENNE                    12.374992
# 4222     14444  CHEYENNE                    12.953952
#
# [4223 rows x 9 columns]

# %%
new_df.min()
# Out:
# STORE                               102
# month_year          2004-08-01 00:00:00
# COST                                8.1
# ORGPRICE                            0.0
# SPRICE                         2.225903
# AMT                                2.36
# QUANTITY                              1
# CITY               ABILENE
# AvgCOGS_peritem                     5.6
# dtype: object

# %% [markdown]
# # New feature 2: Month-over-Month (MoM) Growth

# %%
# Gross Profit for each store
new_df['GrossProfit'] = new_df['AMT'] - new_df['COST']
new_df
# Out:
#       STORE month_year           COST   ORGPRICE     SPRICE         AMT  \
# 0       102 2004-08-01  397048.153125  41.587266  28.507850   633330.40
# 1       102 2004-09-01  449764.833499  42.377500  23.496931   596751.56
# 2       102 2004-10-01  484191.378635  40.596916  30.122991   816995.77
# 3       102 2004-11-01  465410.113387  41.804010  33.310324   843150.92
# 4       102 2004-12-01  873969.452527  41.832542  31.417166  1505699.09
# ...     ...        ...            ...        ...        ...         ...
# 4218   9909 2005-04-01  150799.454641  31.020608  23.042844   254577.34
# 4219   9909 2005-05-01  144000.158786  33.298497  24.336645   248915.20
# 4220   9909 2005-06-01  136023.043130  32.300830  23.481823   233691.10
# 4221   9909 2005-07-01  180687.260000  30.176667  18.414846   268875.17
# 4222   9909 2005-08-01  187106.888741  31.443430  18.969976   274002.34
#
#       QUANTITY                  CITY  AvgCOGS_peritem    GrossProfit
# 0        22216  TAMPA                       17.872171  236282.246875
# 1        25397  TAMPA                       17.709369  146986.726501
# 2        27122  TAMPA                       17.852348  332804.391365
# 3        25312  TAMPA                       18.386936  377740.806613
# 4        47926  TAMPA                       18.235810  631729.637473
# ...        ...                   ...              ...            ...
# 4218     11048  CHEYENNE                    13.649480  103777.885359
# 4219     10228  CHEYENNE                    14.079014  104915.041214
# 4220      9952  CHEYENNE                    13.667910   97668.056870
# 4221     14601  CHEYENNE                    12.374992   88187.910000
# 4222     14444  CHEYENNE                    12.953952   86895.451259
#
# [4223 rows x 10 columns]

# %%
new_df['MoMGrowth'] = new_df.groupby('STORE')['GrossProfit'].pct_change()

# %%
average_growth_per_store = new_df.groupby('STORE')['MoMGrowth'].transform('median') # too many outliers if got mean
new_df['MoMGrowth'].fillna(average_growth_per_store, inplace=True)
new_df
# Out:
#       STORE month_year           COST   ORGPRICE     SPRICE         AMT  \
# 0       102 2004-08-01  397048.153125  41.587266  28.507850   633330.40
# 1       102 2004-09-01  449764.833499  42.377500  23.496931   596751.56
# 2       102 2004-10-01  484191.378635  40.596916  30.122991   816995.77
# 3       102 2004-11-01  465410.113387  41.804010  33.310324   843150.92
# 4       102 2004-12-01  873969.452527  41.832542  31.417166  1505699.09
# ...     ...        ...            ...        ...        ...         ...
# 4218   9909 2005-04-01  150799.454641  31.020608  23.042844   254577.34
# 4219   9909 2005-05-01  144000.158786  33.298497  24.336645   248915.20
# 4220   9909 2005-06-01  136023.043130  32.300830  23.481823   233691.10
# 4221   9909 2005-07-01  180687.260000  30.176667  18.414846   268875.17
# 4222   9909 2005-08-01  187106.888741  31.443430  18.969976   274002.34
#
#       QUANTITY                  CITY  AvgCOGS_peritem    GrossProfit  \
# 0        22216  TAMPA                       17.872171  236282.246875
# 1        25397  TAMPA                       17.709369  146986.726501
# 2        27122  TAMPA                       17.852348  332804.391365
# 3        25312  TAMPA                       18.386936  377740.806613
# 4        47926  TAMPA                       18.235810  631729.637473
# ...        ...                   ...              ...            ...
# 4218     11048  CHEYENNE                    13.649480  103777.885359
# 4219     10228  CHEYENNE                    14.079014  104915.041214
# 4220      9952  CHEYENNE                    13.667910   97668.056870
# 4221     14601  CHEYENNE                    12.374992   88187.910000
# 4222     14444  CHEYENNE                    12.953952   86895.451259
#
#       MoMGrowth
# 0     -0.019383
# 1     -0.377919
# 2      1.264180
# 3      0.135024
# 4      0.672389
# ...         ...
# 4218   0.386736
# 4219   0.010958
# 4220  -0.069075
# 4221  -0.097065
# 4222  -0.014656
#
# [4223 rows x 11 columns]

# %% [markdown]
# # New Feature 3: ReturnPercentage

# %%
df_rperc = df.groupby(['STORE', 'month_year'])['STYPE'].apply(lambda x: (x == 'R').sum() / len(x) * 100).reset_index(name='ReturnPercentage')
new_df['ReturnPercentage'] = df_rperc['ReturnPercentage'].tolist()
new_df
# Out:
#       STORE month_year           COST   ORGPRICE     SPRICE         AMT  \
# 0       102 2004-08-01  397048.153125  41.587266  28.507850   633330.40
# 1       102 2004-09-01  449764.833499  42.377500  23.496931   596751.56
# 2       102 2004-10-01  484191.378635  40.596916  30.122991   816995.77
# 3       102 2004-11-01  465410.113387  41.804010  33.310324   843150.92
# 4       102 2004-12-01  873969.452527  41.832542  31.417166  1505699.09
# ...     ...        ...            ...        ...        ...         ...
# 4218   9909 2005-04-01  150799.454641  31.020608  23.042844   254577.34
# 4219   9909 2005-05-01  144000.158786  33.298497  24.336645   248915.20
# 4220   9909 2005-06-01  136023.043130  32.300830  23.481823   233691.10
# 4221   9909 2005-07-01  180687.260000  30.176667  18.414846   268875.17
# 4222   9909 2005-08-01  187106.888741  31.443430  18.969976   274002.34
#
#       QUANTITY                  CITY  AvgCOGS_peritem    GrossProfit  \
# 0        22216  TAMPA                       17.872171  236282.246875
# 1        25397  TAMPA                       17.709369  146986.726501
# 2        27122  TAMPA                       17.852348  332804.391365
# 3        25312  TAMPA                       18.386936  377740.806613
# 4        47926  TAMPA                       18.235810  631729.637473
# ...        ...                   ...              ...            ...
# 4218     11048  CHEYENNE                    13.649480  103777.885359
# 4219     10228  CHEYENNE                    14.079014  104915.041214
# 4220      9952  CHEYENNE                    13.667910   97668.056870
# 4221     14601  CHEYENNE                    12.374992   88187.910000
# 4222     14444  CHEYENNE                    12.953952   86895.451259
#
#       MoMGrowth  ReturnPercentage
# 0     -0.019383          6.486509
# 1     -0.377919          6.446384
# 2      1.264180          7.227638
# 3      0.135024          6.732009
# 4      0.672389          7.712157
# ...         ...               ...
# 4218   0.386736          6.086365
# 4219   0.010958          7.186933
# 4220  -0.069075          6.369367
# 4221  -0.097065          5.452308
# 4222  -0.014656          4.741806
#
# [4223 rows x 12 columns]

# %%
final_df = new_df[['STORE', 'month_year', 'AvgCOGS_peritem', 'MoMGrowth', 'ReturnPercentage', 'CITY']]
final_df
# Out:
#       STORE month_year  AvgCOGS_peritem  MoMGrowth  ReturnPercentage  \
# 0       102 2004-08-01        17.872171  -0.019383          6.486509
# 1       102 2004-09-01        17.709369  -0.377919          6.446384
# 2       102 2004-10-01        17.852348   1.264180          7.227638
# 3       102 2004-11-01        18.386936   0.135024          6.732009
# 4       102 2004-12-01        18.235810   0.672389          7.712157
# ...     ...        ...              ...        ...               ...
# 4218   9909 2005-04-01        13.649480   0.386736          6.086365
# 4219   9909 2005-05-01        14.079014   0.010958          7.186933
# 4220   9909 2005-06-01        13.667910  -0.069075          6.369367
# 4221   9909 2005-07-01        12.374992  -0.097065          5.452308
# 4222   9909 2005-08-01        12.953952  -0.014656          4.741806
#
#                       CITY
# 0     TAMPA
# 1     TAMPA
# 2     TAMPA
# 3     TAMPA
# 4     TAMPA
# ...                    ...
# 4218  CHEYENNE
# 4219  CHEYENNE
# 4220  CHEYENNE
# 4221  CHEYENNE
# 4222  CHEYENNE
#
# [4223 rows x 6 columns]

# %% [markdown]
# # Store Selection

# %%
store_df = final_df.groupby('STORE').agg({
    'AvgCOGS_peritem': 'mean',
    'MoMGrowth': 'mean',
    'ReturnPercentage': 'mean',
    'CITY': 'first'
}).reset_index()

store_df['success'] = ((store_df['AvgCOGS_peritem'] < store_df['AvgCOGS_peritem'].quantile(0.50)) &
                       (store_df['MoMGrowth'] > store_df['MoMGrowth'].quantile(0.50)) &
                       (store_df['ReturnPercentage'] < store_df['ReturnPercentage'].quantile(0.50))).astype(int)

# %%
store_df
# Out:
#      STORE  AvgCOGS_peritem  MoMGrowth  ReturnPercentage  \
# 0      102        18.656348   0.102883          7.297510
# 1      103        17.761179  -1.857504          8.766210
# 2      107        16.975893   0.350877          8.382016
# 3      202        15.533738   0.190422          8.271629
# 4      203        16.687797  -0.614171         10.119624
# ..     ...              ...        ...               ...
# 326   9709        13.221052  -1.186029          6.835200
# 327   9804        14.891369   0.068109          7.260616
# 328   9806        17.679472   0.040775          4.250364
# 329   9906         5.600000        NaN          0.000000
# 330   9909        13.783600  -0.668611          5.773841
#
#                      CITY  success
# 0    TAMPA                       0
# 1    ST LOUIS                    0
# 2    HURST                       0
# 3    TAMPA                       0
# 4    CHESTERFIELD                0
# ..                    ...      ...
# 326  GREELEY                     0
# 327  LAWTON                      0
# 328  MABELVALE                   0
# 329  LITTLE ROCK                 0
# 330  CHEYENNE                    0
#
# [331 rows x 6 columns]

# %%
store_df.dropna(subset=['MoMGrowth'], inplace=True)

# %%
store_df.nsmallest(3, 'MoMGrowth')
# Out:
#      STORE  AvgCOGS_peritem   MoMGrowth  ReturnPercentage  \
# 18     503        14.155671 -668.679353         10.220279
# 121   3209        15.247958 -102.705764          8.559571
# 312   9209        14.029311   -6.488858          7.035581
#
#                      CITY  success
# 18   ST. LOUIS                   0
# 121  SANDY                       0
# 312  PUEBLO                      0

# %%
# We decide to dismiss the STORE 503 and 3209 due to their outliers features in terms of MoM Growth, and we will not include ST.LOUIS and SANDY as the dataset for prediction too.
store_df.drop([18, 121], axis=0, inplace=True)
store_df
# Out:
#      STORE  AvgCOGS_peritem  MoMGrowth  ReturnPercentage  \
# 0      102        18.656348   0.102883          7.297510
# 1      103        17.761179  -1.857504          8.766210
# 2      107        16.975893   0.350877          8.382016
# 3      202        15.533738   0.190422          8.271629
# 4      203        16.687797  -0.614171         10.119624
# ..     ...              ...        ...               ...
# 325   9704        13.149763   0.078428          6.546315
# 326   9709        13.221052  -1.186029          6.835200
# 327   9804        14.891369   0.068109          7.260616
# 328   9806        17.679472   0.040775          4.250364
# 330   9909        13.783600  -0.668611          5.773841
#
#                      CITY  success
# 0    TAMPA                       0
# 1    ST LOUIS                    0
# 2    HURST                       0
# 3    TAMPA                       0
# 4    CHESTERFIELD                0
# ..                    ...      ...
# 325  SHAWNEE                     0
# 326  GREELEY                     0
# 327  LAWTON                      0
# 328  MABELVALE                   0
# 330  CHEYENNE                    0
#
# [327 rows x 6 columns]

# %%
store_df['success'].value_counts()
# Out:
# success
# 0    277
# 1     50
# Name: count, dtype: int64
